# %% [markdown]
# Dataset Balancing

# %%
import pandas as pd

df = pd.read_csv('/content/MisogynisticAttitudeDetection.csv')

print("SubTask1 class distribution:\n", df['SubTask1'].value_counts(), "\n")
print("SubTask2 class distribution:\n", df['SubTask2'].value_counts(), "\n")

df['Combined'] = df['SubTask1'] + ' + ' + df['SubTask2']
combined_counts = df['Combined'].value_counts()

print("Combined SubTask1 + SubTask2 class distribution:\n", combined_counts)
# Out:
# SubTask1 class distribution:
#  SubTask1
# Neutral        7140
# Pessimistic    3929
# Optimistic     1629
# Name: count, dtype: int64
#
# SubTask2 class distribution:
#  SubTask2
# Nothing         7725
# Criticism       2436
# Offensive       1493
# Suggestion       639
# Appreciation     405
# Name: count, dtype: int64
#
# Combined SubTask1 + SubTask2 class distribution:
#  Combined
# Neutral + Nothing            7140
# Pessimistic + Criticism      2436
# Pessimistic + Offensive      1493
# Optimistic + Suggestion       639
# Optimistic + Nothing          585
# Optimistic + Appreciation     405
# Name: count, dtype: int64

# %%
import pandas as pd
from sklearn.utils import resample

df = pd.read_csv('/content/MisogynisticAttitudeDetection.csv')
df['Combined'] = df['SubTask1'] + ' + ' + df['SubTask2']

upsample_targets = {
    'Pessimistic + Criticism': 2436 + 1605,
    'Pessimistic + Offensive': 1493 + 1606,
    'Optimistic + Suggestion': 639 + 1837,
    'Optimistic + Nothing': 585 + 1837,
    'Optimistic + Appreciation': 405 + 1837,
}

upsampled_dfs = []

for label, target_count in upsample_targets.items():
    subset = df[df['Combined'] == label]
    upsampled = resample(subset, replace=True, n_samples=target_count, random_state=42)
    upsampled_dfs.append(upsampled)

non_upsample_df = df[~df['Combined'].isin(upsample_targets.keys())]
final_df = pd.concat([non_upsample_df] + upsampled_dfs)
final_df = final_df.sample(frac=1, random_state=42).reset_index(drop=True)
final_df.to_csv('/content/balanced_dataset.csv', index=False)

final_df['Combined'].value_counts()
# Out:
# Combined
# Neutral + Nothing            7140
# Pessimistic + Criticism      4041
# Pessimistic + Offensive      3099
# Optimistic + Suggestion      2476
# Optimistic + Nothing         2422
# Optimistic + Appreciation    2242
# Name: count, dtype: int64

# %%
import pandas as pd

df = pd.read_csv('/content/balanced_dataset.csv')

print("SubTask1 class distribution:\n", df['SubTask1'].value_counts(), "\n")
print("SubTask2 class distribution:\n", df['SubTask2'].value_counts(), "\n")

df['Combined'] = df['SubTask1'] + ' + ' + df['SubTask2']
combined_counts = df['Combined'].value_counts()

print("Combined SubTask1 + SubTask2 class distribution:\n", combined_counts)
# Out:
# SubTask1 class distribution:
#  SubTask1
# Neutral        7140
# Pessimistic    7140
# Optimistic     7140
# Name: count, dtype: int64
#
# SubTask2 class distribution:
#  SubTask2
# Nothing         9562
# Criticism       4041
# Offensive       3099
# Suggestion      2476
# Appreciation    2242
# Name: count, dtype: int64
#
# Combined SubTask1 + SubTask2 class distribution:
#  Combined
# Neutral + Nothing            7140
# Pessimistic + Criticism      4041
# Pessimistic + Offensive      3099
# Optimistic + Suggestion      2476
# Optimistic + Nothing         2422
# Optimistic + Appreciation    2242
# Name: count, dtype: int64

# %% [markdown]
# Preprocessing

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 13.3 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.14.1

# %%
import pandas as pd
import re
import emoji

df = pd.read_csv('balanced_dataset.csv')

def clean_text(text):
    if pd.isnull(text):
        return ""
    text = text.lower()
    text = emoji.demojize(text, delimiters=(" ", " "))
    text = re.sub(r'http\S+|www\S+|@\w+|#\w+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

df['Cleaned_Comments'] = df['Comments'].apply(clean_text)
df.to_csv('cleaned_balanced_dataset.csv', index=False)

# %% [markdown]
# KNN

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

dataset = pd.read_csv('/content/cleaned_balanced_dataset.csv')

subtask1_mapping = {'Optimistic': 0, 'Pessimistic': 1, 'Neutral': 2}
subtask2_mapping = {'Appreciation': 0, 'Suggestion': 1, 'Criticism': 2, 'Offensive': 3, 'Nothing': 4}

dataset['SubTask1_Num'] = dataset['SubTask1'].map(subtask1_mapping)
dataset['SubTask2_Num'] = dataset['SubTask2'].map(subtask2_mapping)

model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
X = model.encode(dataset['Comments'].tolist(), show_progress_bar=True)

y1 = dataset['SubTask1_Num'].values
y2 = dataset['SubTask2_Num'].values

X_train, X_test, y1_train, y1_test = train_test_split(X, y1, test_size=0.2, random_state=42)
_, _, y2_train, y2_test = train_test_split(X, y2, test_size=0.2, random_state=42)

knn1 = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2)
knn1.fit(X_train, y1_train)

subtask2_models = {}
for label in subtask1_mapping.values():
    subset_indices = y1_train == label
    if np.any(subset_indices):
        knn2 = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2)
        knn2.fit(X_train[subset_indices], y2_train[subset_indices])
        subtask2_models[label] = knn2

subtask1_preds = knn1.predict(X_test)

subtask2_preds = []
for i, subtask1_pred in enumerate(subtask1_preds):
    if subtask1_pred in subtask2_models:
        pred = subtask2_models[subtask1_pred].predict(X_test[i].reshape(1, -1))[0]
        subtask2_preds.append(pred)
    else:
        subtask2_preds.append(None)

print("SubTask1 Classification Report:\n", classification_report(y1_test, subtask1_preds))
print("SubTask2 Classification Report:\n", classification_report(y2_test, subtask2_preds))
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/670 [00:00<?, ?it/s]
# SubTask1 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.89      0.74      1408
#            1       0.62      0.69      0.66      1422
#            2       0.70      0.35      0.46      1454
#
#     accuracy                           0.64      4284
#    macro avg       0.65      0.64      0.62      4284
# weighted avg       0.65      0.64      0.62      4284
#
# SubTask2 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.90      0.72       415
#            1       0.58      0.76      0.66       514
#            2       0.49      0.52      0.50       817
#            3       0.46      0.54      0.50       605
#            4       0.77      0.55      0.64      1933
#
#     accuracy                           0.60      4284
#    macro avg       0.58      0.66      0.60      4284
# weighted avg       0.63      0.60      0.60      4284

# %% [markdown]
# Logistic Regresssion

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

file_path = '/content/cleaned_balanced_dataset.csv'
dataset = pd.read_csv(file_path)

subtask1_mapping = {'Optimistic': 0, 'Pessimistic': 1, 'Neutral': 2}
subtask2_mapping = {'Appreciation': 0, 'Suggestion': 1, 'Criticism': 2, 'Offensive': 3, 'Nothing': 4}
default_subtask2_label = subtask2_mapping['Nothing']

dataset['SubTask1_Num'] = dataset['SubTask1'].map(subtask1_mapping)
dataset['SubTask2_Num'] = dataset['SubTask2'].map(subtask2_mapping)

embedder = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
X = embedder.encode(dataset['Comments'].tolist(), show_progress_bar=True)

y1 = dataset['SubTask1_Num'].values
y2 = dataset['SubTask2_Num'].values

X_train, X_test, y1_train, y1_test = train_test_split(X, y1, test_size=0.2, random_state=42)
_, _, y2_train, y2_test = train_test_split(X, y2, test_size=0.2, random_state=42)

lr1 = LogisticRegression(C=1.0, solver='lbfgs', max_iter=100, penalty='l2')
lr1.fit(X_train, y1_train)

subtask2_models = {}
for label in subtask1_mapping.values():
    subset_indices = y1_train == label
    y2_subset = y2_train[subset_indices]
    if len(np.unique(y2_subset)) > 1:
        lr2 = LogisticRegression(C=1.0, solver='lbfgs', max_iter=100, penalty='l2')
        lr2.fit(X_train[subset_indices], y2_subset)
        subtask2_models[label] = lr2

subtask1_preds = lr1.predict(X_test)

subtask2_preds = []
for i, subtask1_pred in enumerate(subtask1_preds):
    if subtask1_pred in subtask2_models:
        pred = subtask2_models[subtask1_pred].predict(X_test[i].reshape(1, -1))[0]
        subtask2_preds.append(pred)
    else:
        subtask2_preds.append(default_subtask2_label)

print("SubTask1 Classification Report:\n", classification_report(y1_test, subtask1_preds))
print("SubTask2 Classification Report:\n", classification_report(y2_test, subtask2_preds))
# Out:
# Batches:   0%|          | 0/670 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# SubTask1 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.64      0.63      1408
#            1       0.58      0.57      0.58      1422
#            2       0.58      0.56      0.57      1454
#
#     accuracy                           0.59      4284
#    macro avg       0.59      0.59      0.59      4284
# weighted avg       0.59      0.59      0.59      4284
#
# SubTask2 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.54      0.52       415
#            1       0.46      0.53      0.49       514
#            2       0.43      0.44      0.43       817
#            3       0.41      0.38      0.39       605
#            4       0.66      0.63      0.65      1933
#
#     accuracy                           0.54      4284
#    macro avg       0.49      0.50      0.50      4284
# weighted avg       0.54      0.54      0.54      4284

# %% [markdown]
# SVM

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sentence_transformers import SentenceTransformer

file_path = '/content/cleaned_balanced_dataset.csv'
dataset = pd.read_csv(file_path)

subtask1_mapping = {'Optimistic': 0, 'Pessimistic': 1, 'Neutral': 2}
subtask2_mapping = {'Appreciation': 0, 'Suggestion': 1, 'Criticism': 2, 'Offensive': 3, 'Nothing': 4}
default_subtask2_label = subtask2_mapping['Nothing']

dataset['SubTask1_Num'] = dataset['SubTask1'].map(subtask1_mapping)
dataset['SubTask2_Num'] = dataset['SubTask2'].map(subtask2_mapping)

print("Loading SentenceTransformer model...")
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

print("Encoding comments into embeddings...")
X = model.encode(dataset['Comments'].tolist(), show_progress_bar=True)

y1 = dataset['SubTask1_Num']
y2 = dataset['SubTask2_Num']

X_train, X_test, y1_train, y1_test = train_test_split(X, y1, test_size=0.2, random_state=42)
_, _, y2_train, y2_test = train_test_split(X, y2, test_size=0.2, random_state=42)

print("Training SVM for SubTask1...")
svm1 = SVC(kernel='linear', C=0.1)
svm1.fit(X_train, y1_train)

subtask2_models = {}
for label in subtask1_mapping.values():
    subset_indices = y1_train == label
    y2_subset = y2_train[subset_indices]
    if len(np.unique(y2_subset)) > 1:
        svm2 = SVC(kernel='linear', C=0.1)
        svm2.fit(X_train[subset_indices], y2_subset)
        subtask2_models[label] = svm2

subtask1_preds = svm1.predict(X_test)

subtask2_preds = []
for i, subtask1_pred in enumerate(subtask1_preds):
    if subtask1_pred in subtask2_models:
        subtask2_preds.append(subtask2_models[subtask1_pred].predict(X_test[i].reshape(1, -1))[0])
    else:
        subtask2_preds.append(default_subtask2_label)

print("\nSubTask1 Classification Report:\n", classification_report(y1_test, subtask1_preds))
print("\nSubTask2 Classification Report:\n", classification_report(y2_test, subtask2_preds))
# Out:
# Loading SentenceTransformer model...
# Encoding comments into embeddings...
# Batches:   0%|          | 0/670 [00:00<?, ?it/s]
# Training SVM for SubTask1...
#
# SubTask1 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.59      0.61      0.60      1408
#            1       0.56      0.59      0.58      1422
#            2       0.58      0.54      0.56      1454
#
#     accuracy                           0.58      4284
#    macro avg       0.58      0.58      0.58      4284
# weighted avg       0.58      0.58      0.58      4284
#
#
# SubTask2 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.53      0.51       415
#            1       0.46      0.50      0.48       514
#            2       0.39      0.48      0.43       817
#            3       0.40      0.34      0.37       605
#            4       0.66      0.62      0.64      1933
#
#     accuracy                           0.53      4284
#    macro avg       0.48      0.49      0.49      4284
# weighted avg       0.54      0.53      0.53      4284

# %% [markdown]
# Decision Tree

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score

file_path = '/content/cleaned_balanced_dataset.csv'
dataset = pd.read_csv(file_path)

subtask1_mapping = {'Optimistic': 0, 'Pessimistic': 1, 'Neutral': 2}
subtask2_mapping = {'Appreciation': 0, 'Suggestion': 1, 'Criticism': 2, 'Offensive': 3, 'Nothing': 4}
default_subtask2_label = subtask2_mapping['Nothing']

dataset['SubTask1_Num'] = dataset['SubTask1'].map(subtask1_mapping)
dataset['SubTask2_Num'] = dataset['SubTask2'].map(subtask2_mapping)

model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
X = model.encode(dataset['Comments'], show_progress_bar=True)

y1 = dataset['SubTask1_Num']
y2 = dataset['SubTask2_Num']

X_train, X_test, y1_train, y1_test = train_test_split(X, y1, test_size=0.2, random_state=42)
_, _, y2_train, y2_test = train_test_split(X, y2, test_size=0.2, random_state=42)

dt1 = DecisionTreeClassifier(criterion='gini', max_depth=10, min_samples_split=10)
dt1.fit(X_train, y1_train)

train_acc_y1 = accuracy_score(y1_train, dt1.predict(X_train))
test_acc_y1 = accuracy_score(y1_test, dt1.predict(X_test))
print(f"SubTask1 - Train Accuracy: {train_acc_y1:.4f}")
print(f"SubTask1 - Test Accuracy: {test_acc_y1:.4f}")

subtask2_models = {}
for label in subtask1_mapping.values():
    subset_indices = y1_train == label
    y2_subset = y2_train[subset_indices]
    if len(np.unique(y2_subset)) > 1:
        dt2 = DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_split=10)
        dt2.fit(X_train[subset_indices], y2_subset)
        subtask2_models[label] = dt2

subtask1_preds = dt1.predict(X_test)

subtask2_preds = []
subtask2_train_preds = []
for i, subtask1_pred in enumerate(subtask1_preds):
    if subtask1_pred in subtask2_models:
        pred = subtask2_models[subtask1_pred].predict(X_test[i].reshape(1, -1))[0]
        subtask2_preds.append(pred)
    else:
        subtask2_preds.append(default_subtask2_label)

for i in range(len(X_train)):
    label = y1_train.iloc[i]
    if label in subtask2_models:
        pred = subtask2_models[label].predict(X_train[i].reshape(1, -1))[0]
        subtask2_train_preds.append(pred)
    else:
        subtask2_train_preds.append(default_subtask2_label)

train_acc_y2 = accuracy_score(y2_train, subtask2_train_preds)
test_acc_y2 = accuracy_score(y2_test, subtask2_preds)
print(f"SubTask2 - Train Accuracy: {train_acc_y2:.4f}")
print(f"SubTask2 - Test Accuracy: {test_acc_y2:.4f}")

print("SubTask1 Classification Report:\n", classification_report(y1_test, subtask1_preds))
print("SubTask2 Classification Report:\n", classification_report(y2_test, subtask2_preds))
# Out:
# Batches:   0%|          | 0/670 [00:00<?, ?it/s]
# SubTask1 - Train Accuracy: 0.7615
# SubTask1 - Test Accuracy: 0.6424
# SubTask2 - Train Accuracy: 0.9455
# SubTask2 - Test Accuracy: 0.6324
# SubTask1 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.76      0.74      1408
#            1       0.59      0.68      0.63      1422
#            2       0.61      0.50      0.55      1454
#
#     accuracy                           0.64      4284
#    macro avg       0.64      0.64      0.64      4284
# weighted avg       0.64      0.64      0.64      4284
#
# SubTask2 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.79      0.74       415
#            1       0.69      0.68      0.69       514
#            2       0.52      0.62      0.57       817
#            3       0.48      0.51      0.50       605
#            4       0.72      0.63      0.67      1933
#
#     accuracy                           0.63      4284
#    macro avg       0.62      0.65      0.63      4284
# weighted avg       0.64      0.63      0.63      4284

# %% [markdown]
# MNB

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report

file_path = '/content/cleaned_balanced_dataset.csv'
dataset = pd.read_csv(file_path)

subtask1_mapping = {'Optimistic': 0, 'Pessimistic': 1, 'Neutral': 2}
subtask2_mapping = {'Appreciation': 0, 'Suggestion': 1, 'Criticism': 2, 'Offensive': 3, 'Nothing': 4}
default_subtask2_label = subtask2_mapping['Nothing']

dataset['SubTask1_Num'] = dataset['SubTask1'].map(subtask1_mapping)
dataset['SubTask2_Num'] = dataset['SubTask2'].map(subtask2_mapping)

embedder = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
X = embedder.encode(dataset['Comments'].tolist(), show_progress_bar=True)

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y1_train, y1_test = train_test_split(X_scaled, dataset['SubTask1_Num'].values, test_size=0.2, random_state=42)
_, _, y2_train, y2_test = train_test_split(X_scaled, dataset['SubTask2_Num'].values, test_size=0.2, random_state=42)

mnb1 = MultinomialNB()
mnb1.fit(X_train, y1_train)

subtask2_models = {}
for label in subtask1_mapping.values():
    indices = y1_train == label
    y2_subset = y2_train[indices]
    if len(np.unique(y2_subset)) > 1:
        mnb2 = MultinomialNB()
        mnb2.fit(X_train[indices], y2_subset)
        subtask2_models[label] = mnb2

subtask1_preds = mnb1.predict(X_test)

subtask2_preds = []
for i, subtask1_pred in enumerate(subtask1_preds):
    if subtask1_pred in subtask2_models:
        pred = subtask2_models[subtask1_pred].predict(X_test[i].reshape(1, -1))[0]
        subtask2_preds.append(pred)
    else:
        subtask2_preds.append(default_subtask2_label)

print("\nSubTask1 Classification Report:\n", classification_report(y1_test, subtask1_preds))
print("\nSubTask2 Classification Report:\n", classification_report(y2_test, subtask2_preds))
# Out:
# Generating sentence embeddings...
# Batches:   0%|          | 0/670 [00:00<?, ?it/s]
# Scaling features for MultinomialNB...
# Training MNB for SubTask1...
# Training separate MNBs for SubTask2 by SubTask1 category...
#
# SubTask1 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.35      0.41      1408
#            1       0.48      0.46      0.47      1422
#            2       0.45      0.61      0.52      1454
#
#     accuracy                           0.47      4284
#    macro avg       0.48      0.47      0.47      4284
# weighted avg       0.48      0.47      0.47      4284
#
#
# SubTask2 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.37      0.31      0.34       415
#            1       0.28      0.23      0.26       514
#            2       0.33      0.54      0.41       817
#            3       0.21      0.01      0.03       605
#            4       0.58      0.64      0.61      1933
#
#     accuracy                           0.45      4284
#    macro avg       0.35      0.35      0.33      4284
# weighted avg       0.42      0.45      0.42      4284

# %% [markdown]
# MLP

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

dataset = pd.read_csv('/content/cleaned_balanced_dataset.csv')

le1 = LabelEncoder()
dataset['SubTask1_Num'] = le1.fit_transform(dataset['SubTask1'])

le2 = LabelEncoder()
dataset['SubTask2_Num'] = le2.fit_transform(dataset['SubTask2'])

model_name = 'sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2'
sbert = SentenceTransformer(model_name)

X = sbert.encode(dataset['Comments'].tolist(), show_progress_bar=True)

y1 = np.array(dataset['SubTask1_Num'].values)
y2 = np.array(dataset['SubTask2_Num'].values)

X_train, X_test, y1_train, y1_test, y2_train, y2_test = train_test_split(X, y1, y2, test_size=0.2, random_state=42)

input_dim = X.shape[1]
inputs = Input(shape=(input_dim,))
x = Dense(256, activation='relu')(inputs)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)

subtask1_output = Dense(3, activation='softmax', name='subtask1_output')(x)
subtask2_output = Dense(5, activation='softmax', name='subtask2_output')(x)

model = Model(inputs=inputs, outputs=[subtask1_output, subtask2_output])
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss={'subtask1_output': 'sparse_categorical_crossentropy',
                    'subtask2_output': 'sparse_categorical_crossentropy'},
              metrics={'subtask1_output': 'accuracy',
                       'subtask2_output': 'accuracy'})

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

model.fit(X_train,
          {'subtask1_output': y1_train, 'subtask2_output': y2_train},
          validation_split=0.2,
          epochs=50,
          batch_size=32,
          callbacks=[early_stop])

results = model.evaluate(X_test, {'subtask1_output': y1_test, 'subtask2_output': y2_test})
print(f'Subtask 1 - Loss: {results[1]}, Accuracy: {results[2]}')
print(f'Subtask 2 - Loss: {results[3]}, Accuracy: {results[4]}')
# Out:
# Generating sentence embeddings...
# Batches:   0%|          | 0/670 [00:00<?, ?it/s]
# Epoch 1/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 2.5664 - subtask1_output_accuracy: 0.3602 - subtask1_output_loss: 1.0985 - subtask2_output_accuracy: 0.4247 - subtask2_output_loss: 1.4678 - val_loss: 2.3654 - val_subtask1_output_accuracy: 0.5018 - val_subtask1_output_loss: 1.0317 - val_subtask2_output_accuracy: 0.4825 - val_subtask2_output_loss: 1.3312
# Epoch 2/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 2.4084 - subtask1_output_accuracy: 0.4649 - subtask1_output_loss: 1.0377 - subtask2_output_accuracy: 0.4554 - subtask2_output_loss: 1.3707 - val_loss: 2.2658 - val_subtask1_output_accuracy: 0.5315 - val_subtask1_output_loss: 0.9862 - val_subtask2_output_accuracy: 0.5032 - val_subtask2_output_loss: 1.2772
# Epoch 3/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.3042 - subtask1_output_accuracy: 0.5105 - subtask1_output_loss: 0.9958 - subtask2_output_accuracy: 0.4820 - subtask2_output_loss: 1.3084 - val_loss: 2.1991 - val_subtask1_output_accuracy: 0.5446 - val_subtask1_output_loss: 0.9584 - val_subtask2_output_accuracy: 0.5204 - val_subtask2_output_loss: 1.2377
# Epoch 4/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.2531 - subtask1_output_accuracy: 0.5195 - subtask1_output_loss: 0.9790 - subtask2_output_accuracy: 0.4905 - subtask2_output_loss: 1.2740 - val_loss: 2.1507 - val_subtask1_output_accuracy: 0.5505 - val_subtask1_output_loss: 0.9411 - val_subtask2_output_accuracy: 0.5257 - val_subtask2_output_loss: 1.2059
# Epoch 5/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.1999 - subtask1_output_accuracy: 0.5300 - subtask1_output_loss: 0.9590 - subtask2_output_accuracy: 0.5031 - subtask2_output_loss: 1.2408 - val_loss: 2.1142 - val_subtask1_output_accuracy: 0.5709 - val_subtask1_output_loss: 0.9249 - val_subtask2_output_accuracy: 0.5335 - val_subtask2_output_loss: 1.1857
# Epoch 6/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 2.1565 - subtask1_output_accuracy: 0.5486 - subtask1_output_loss: 0.9373 - subtask2_output_accuracy: 0.5030 - subtask2_output_loss: 1.2192 - val_loss: 2.0872 - val_subtask1_output_accuracy: 0.5744 - val_subtask1_output_loss: 0.9148 - val_subtask2_output_accuracy: 0.5423 - val_subtask2_output_loss: 1.1695
# Epoch 7/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.1262 - subtask1_output_accuracy: 0.5583 - subtask1_output_loss: 0.9275 - subtask2_output_accuracy: 0.5092 - subtask2_output_loss: 1.1987 - val_loss: 2.0620 - val_subtask1_output_accuracy: 0.5764 - val_subtask1_output_loss: 0.9039 - val_subtask2_output_accuracy: 0.5493 - val_subtask2_output_loss: 1.1547
# Epoch 8/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.0835 - subtask1_output_accuracy: 0.5740 - subtask1_output_loss: 0.9108 - subtask2_output_accuracy: 0.5250 - subtask2_output_loss: 1.1727 - val_loss: 2.0386 - val_subtask1_output_accuracy: 0.5823 - val_subtask1_output_loss: 0.8957 - val_subtask2_output_accuracy: 0.5528 - val_subtask2_output_loss: 1.1398
# Epoch 9/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2.0609 - subtask1_output_accuracy: 0.5872 - subtask1_output_loss: 0.8923 - subtask2_output_accuracy: 0.5161 - subtask2_output_loss: 1.1686 - val_loss: 2.0095 - val_subtask1_output_accuracy: 0.5963 - val_subtask1_output_loss: 0.8812 - val_subtask2_output_accuracy: 0.5601 - val_subtask2_output_loss: 1.1256
# Epoch 10/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.0255 - subtask1_output_accuracy: 0.5901 - subtask1_output_loss: 0.8788 - subtask2_output_accuracy: 0.5424 - subtask2_output_loss: 1.1467 - val_loss: 1.9812 - val_subtask1_output_accuracy: 0.5992 - val_subtask1_output_loss: 0.8709 - val_subtask2_output_accuracy: 0.5636 - val_subtask2_output_loss: 1.1074
# Epoch 11/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.9907 - subtask1_output_accuracy: 0.5912 - subtask1_output_loss: 0.8715 - subtask2_output_accuracy: 0.5472 - subtask2_output_loss: 1.1192 - val_loss: 1.9685 - val_subtask1_output_accuracy: 0.5939 - val_subtask1_output_loss: 0.8661 - val_subtask2_output_accuracy: 0.5735 - val_subtask2_output_loss: 1.0998
# Epoch 12/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9587 - subtask1_output_accuracy: 0.6051 - subtask1_output_loss: 0.8556 - subtask2_output_accuracy: 0.5562 - subtask2_output_loss: 1.1031 - val_loss: 1.9397 - val_subtask1_output_accuracy: 0.6111 - val_subtask1_output_loss: 0.8516 - val_subtask2_output_accuracy: 0.5779 - val_subtask2_output_loss: 1.0858
# Epoch 13/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9354 - subtask1_output_accuracy: 0.6140 - subtask1_output_loss: 0.8438 - subtask2_output_accuracy: 0.5537 - subtask2_output_loss: 1.0916 - val_loss: 1.9130 - val_subtask1_output_accuracy: 0.6170 - val_subtask1_output_loss: 0.8442 - val_subtask2_output_accuracy: 0.5697 - val_subtask2_output_loss: 1.0659
# Epoch 14/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.8898 - subtask1_output_accuracy: 0.6335 - subtask1_output_loss: 0.8225 - subtask2_output_accuracy: 0.5643 - subtask2_output_loss: 1.0673 - val_loss: 1.8939 - val_subtask1_output_accuracy: 0.6231 - val_subtask1_output_loss: 0.8350 - val_subtask2_output_accuracy: 0.5884 - val_subtask2_output_loss: 1.0569
# Epoch 15/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.8529 - subtask1_output_accuracy: 0.6340 - subtask1_output_loss: 0.8083 - subtask2_output_accuracy: 0.5686 - subtask2_output_loss: 1.0446 - val_loss: 1.8584 - val_subtask1_output_accuracy: 0.6251 - val_subtask1_output_loss: 0.8203 - val_subtask2_output_accuracy: 0.5904 - val_subtask2_output_loss: 1.0363
# Epoch 16/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.8286 - subtask1_output_accuracy: 0.6359 - subtask1_output_loss: 0.8010 - subtask2_output_accuracy: 0.5812 - subtask2_output_loss: 1.0277 - val_loss: 1.8423 - val_subtask1_output_accuracy: 0.6249 - val_subtask1_output_loss: 0.8143 - val_subtask2_output_accuracy: 0.6041 - val_subtask2_output_loss: 1.0260
# Epoch 17/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.8124 - subtask1_output_accuracy: 0.6433 - subtask1_output_loss: 0.7910 - subtask2_output_accuracy: 0.5824 - subtask2_output_loss: 1.0214 - val_loss: 1.8163 - val_subtask1_output_accuracy: 0.6421 - val_subtask1_output_loss: 0.8025 - val_subtask2_output_accuracy: 0.6079 - val_subtask2_output_loss: 1.0112
# Epoch 18/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7597 - subtask1_output_accuracy: 0.6552 - subtask1_output_loss: 0.7669 - subtask2_output_accuracy: 0.6021 - subtask2_output_loss: 0.9929 - val_loss: 1.7897 - val_subtask1_output_accuracy: 0.6461 - val_subtask1_output_loss: 0.7921 - val_subtask2_output_accuracy: 0.6129 - val_subtask2_output_loss: 0.9951
# Epoch 19/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7299 - subtask1_output_accuracy: 0.6647 - subtask1_output_loss: 0.7601 - subtask2_output_accuracy: 0.6135 - subtask2_output_loss: 0.9698 - val_loss: 1.7671 - val_subtask1_output_accuracy: 0.6532 - val_subtask1_output_loss: 0.7835 - val_subtask2_output_accuracy: 0.6170 - val_subtask2_output_loss: 0.9811
# Epoch 20/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7193 - subtask1_output_accuracy: 0.6642 - subtask1_output_loss: 0.7543 - subtask2_output_accuracy: 0.6064 - subtask2_output_loss: 0.9650 - val_loss: 1.7464 - val_subtask1_output_accuracy: 0.6546 - val_subtask1_output_loss: 0.7739 - val_subtask2_output_accuracy: 0.6219 - val_subtask2_output_loss: 0.9695
# Epoch 21/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.6626 - subtask1_output_accuracy: 0.6820 - subtask1_output_loss: 0.7252 - subtask2_output_accuracy: 0.6250 - subtask2_output_loss: 0.9374 - val_loss: 1.7285 - val_subtask1_output_accuracy: 0.6634 - val_subtask1_output_loss: 0.7678 - val_subtask2_output_accuracy: 0.6310 - val_subtask2_output_loss: 0.9591
# Epoch 22/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.6573 - subtask1_output_accuracy: 0.6844 - subtask1_output_loss: 0.7251 - subtask2_output_accuracy: 0.6237 - subtask2_output_loss: 0.9323 - val_loss: 1.7096 - val_subtask1_output_accuracy: 0.6569 - val_subtask1_output_loss: 0.7607 - val_subtask2_output_accuracy: 0.6339 - val_subtask2_output_loss: 0.9472
# Epoch 23/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.6139 - subtask1_output_accuracy: 0.6888 - subtask1_output_loss: 0.7083 - subtask2_output_accuracy: 0.6459 - subtask2_output_loss: 0.9056 - val_loss: 1.6790 - val_subtask1_output_accuracy: 0.6689 - val_subtask1_output_loss: 0.7466 - val_subtask2_output_accuracy: 0.6371 - val_subtask2_output_loss: 0.9301
# Epoch 24/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.5933 - subtask1_output_accuracy: 0.7044 - subtask1_output_loss: 0.6955 - subtask2_output_accuracy: 0.6381 - subtask2_output_loss: 0.8978 - val_loss: 1.6582 - val_subtask1_output_accuracy: 0.6812 - val_subtask1_output_loss: 0.7365 - val_subtask2_output_accuracy: 0.6429 - val_subtask2_output_loss: 0.9191
# Epoch 25/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.5604 - subtask1_output_accuracy: 0.7072 - subtask1_output_loss: 0.6889 - subtask2_output_accuracy: 0.6507 - subtask2_output_loss: 0.8715 - val_loss: 1.6528 - val_subtask1_output_accuracy: 0.6777 - val_subtask1_output_loss: 0.7382 - val_subtask2_output_accuracy: 0.6561 - val_subtask2_output_loss: 0.9139
# Epoch 26/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5388 - subtask1_output_accuracy: 0.7055 - subtask1_output_loss: 0.6806 - subtask2_output_accuracy: 0.6562 - subtask2_output_loss: 0.8582 - val_loss: 1.6237 - val_subtask1_output_accuracy: 0.6855 - val_subtask1_output_loss: 0.7242 - val_subtask2_output_accuracy: 0.6567 - val_subtask2_output_loss: 0.8977
# Epoch 27/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.5145 - subtask1_output_accuracy: 0.7140 - subtask1_output_loss: 0.6707 - subtask2_output_accuracy: 0.6716 - subtask2_output_loss: 0.8439 - val_loss: 1.6039 - val_subtask1_output_accuracy: 0.6847 - val_subtask1_output_loss: 0.7165 - val_subtask2_output_accuracy: 0.6587 - val_subtask2_output_loss: 0.8861
# Epoch 28/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.4882 - subtask1_output_accuracy: 0.7183 - subtask1_output_loss: 0.6554 - subtask2_output_accuracy: 0.6688 - subtask2_output_loss: 0.8327 - val_loss: 1.5806 - val_subtask1_output_accuracy: 0.7001 - val_subtask1_output_loss: 0.7054 - val_subtask2_output_accuracy: 0.6666 - val_subtask2_output_loss: 0.8731
# Epoch 29/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.4664 - subtask1_output_accuracy: 0.7267 - subtask1_output_loss: 0.6452 - subtask2_output_accuracy: 0.6793 - subtask2_output_loss: 0.8212 - val_loss: 1.5682 - val_subtask1_output_accuracy: 0.6960 - val_subtask1_output_loss: 0.7004 - val_subtask2_output_accuracy: 0.6680 - val_subtask2_output_loss: 0.8660
# Epoch 30/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.4365 - subtask1_output_accuracy: 0.7330 - subtask1_output_loss: 0.6293 - subtask2_output_accuracy: 0.6856 - subtask2_output_loss: 0.8073 - val_loss: 1.5587 - val_subtask1_output_accuracy: 0.7007 - val_subtask1_output_loss: 0.6951 - val_subtask2_output_accuracy: 0.6674 - val_subtask2_output_loss: 0.8608
# Epoch 31/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.4036 - subtask1_output_accuracy: 0.7430 - subtask1_output_loss: 0.6187 - subtask2_output_accuracy: 0.6985 - subtask2_output_loss: 0.7848 - val_loss: 1.5408 - val_subtask1_output_accuracy: 0.7045 - val_subtask1_output_loss: 0.6910 - val_subtask2_output_accuracy: 0.6794 - val_subtask2_output_loss: 0.8489
# Epoch 32/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.3716 - subtask1_output_accuracy: 0.7442 - subtask1_output_loss: 0.6053 - subtask2_output_accuracy: 0.7023 - subtask2_output_loss: 0.7663 - val_loss: 1.5270 - val_subtask1_output_accuracy: 0.7092 - val_subtask1_output_loss: 0.6822 - val_subtask2_output_accuracy: 0.6683 - val_subtask2_output_loss: 0.8421
# Epoch 33/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.3793 - subtask1_output_accuracy: 0.7401 - subtask1_output_loss: 0.6112 - subtask2_output_accuracy: 0.6998 - subtask2_output_loss: 0.7681 - val_loss: 1.5106 - val_subtask1_output_accuracy: 0.7130 - val_subtask1_output_loss: 0.6781 - val_subtask2_output_accuracy: 0.6739 - val_subtask2_output_loss: 0.8308
# Epoch 34/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.3695 - subtask1_output_accuracy: 0.7415 - subtask1_output_loss: 0.6035 - subtask2_output_accuracy: 0.7054 - subtask2_output_loss: 0.7660 - val_loss: 1.5000 - val_subtask1_output_accuracy: 0.7188 - val_subtask1_output_loss: 0.6717 - val_subtask2_output_accuracy: 0.6817 - val_subtask2_output_loss: 0.8257
# Epoch 35/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.3352 - subtask1_output_accuracy: 0.7513 - subtask1_output_loss: 0.5867 - subtask2_output_accuracy: 0.7105 - subtask2_output_loss: 0.7485 - val_loss: 1.4921 - val_subtask1_output_accuracy: 0.7223 - val_subtask1_output_loss: 0.6697 - val_subtask2_output_accuracy: 0.6937 - val_subtask2_output_loss: 0.8212
# Epoch 36/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.3109 - subtask1_output_accuracy: 0.7639 - subtask1_output_loss: 0.5753 - subtask2_output_accuracy: 0.7172 - subtask2_output_loss: 0.7356 - val_loss: 1.4648 - val_subtask1_output_accuracy: 0.7272 - val_subtask1_output_loss: 0.6587 - val_subtask2_output_accuracy: 0.6928 - val_subtask2_output_loss: 0.8039
# Epoch 37/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.2988 - subtask1_output_accuracy: 0.7616 - subtask1_output_loss: 0.5721 - subtask2_output_accuracy: 0.7148 - subtask2_output_loss: 0.7267 - val_loss: 1.4552 - val_subtask1_output_accuracy: 0.7232 - val_subtask1_output_loss: 0.6523 - val_subtask2_output_accuracy: 0.6954 - val_subtask2_output_loss: 0.8000
# Epoch 38/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.2705 - subtask1_output_accuracy: 0.7598 - subtask1_output_loss: 0.5607 - subtask2_output_accuracy: 0.7209 - subtask2_output_loss: 0.7098 - val_loss: 1.4377 - val_subtask1_output_accuracy: 0.7290 - val_subtask1_output_loss: 0.6470 - val_subtask2_output_accuracy: 0.7045 - val_subtask2_output_loss: 0.7878
# Epoch 39/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.2430 - subtask1_output_accuracy: 0.7741 - subtask1_output_loss: 0.5479 - subtask2_output_accuracy: 0.7329 - subtask2_output_loss: 0.6951 - val_loss: 1.4261 - val_subtask1_output_accuracy: 0.7287 - val_subtask1_output_loss: 0.6418 - val_subtask2_output_accuracy: 0.7045 - val_subtask2_output_loss: 0.7822
# Epoch 40/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.2325 - subtask1_output_accuracy: 0.7718 - subtask1_output_loss: 0.5486 - subtask2_output_accuracy: 0.7363 - subtask2_output_loss: 0.6840 - val_loss: 1.4154 - val_subtask1_output_accuracy: 0.7331 - val_subtask1_output_loss: 0.6380 - val_subtask2_output_accuracy: 0.7048 - val_subtask2_output_loss: 0.7756
# Epoch 41/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 1.2365 - subtask1_output_accuracy: 0.7739 - subtask1_output_loss: 0.5445 - subtask2_output_accuracy: 0.7359 - subtask2_output_loss: 0.6920 - val_loss: 1.4141 - val_subtask1_output_accuracy: 0.7360 - val_subtask1_output_loss: 0.6401 - val_subtask2_output_accuracy: 0.7115 - val_subtask2_output_loss: 0.7713
# Epoch 42/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.1842 - subtask1_output_accuracy: 0.7888 - subtask1_output_loss: 0.5220 - subtask2_output_accuracy: 0.7401 - subtask2_output_loss: 0.6622 - val_loss: 1.4019 - val_subtask1_output_accuracy: 0.7360 - val_subtask1_output_loss: 0.6326 - val_subtask2_output_accuracy: 0.7135 - val_subtask2_output_loss: 0.7664
# Epoch 43/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1768 - subtask1_output_accuracy: 0.7863 - subtask1_output_loss: 0.5229 - subtask2_output_accuracy: 0.7532 - subtask2_output_loss: 0.6539 - val_loss: 1.3812 - val_subtask1_output_accuracy: 0.7357 - val_subtask1_output_loss: 0.6242 - val_subtask2_output_accuracy: 0.7127 - val_subtask2_output_loss: 0.7545
# Epoch 44/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1624 - subtask1_output_accuracy: 0.7815 - subtask1_output_loss: 0.5203 - subtask2_output_accuracy: 0.7523 - subtask2_output_loss: 0.6421 - val_loss: 1.3900 - val_subtask1_output_accuracy: 0.7415 - val_subtask1_output_loss: 0.6297 - val_subtask2_output_accuracy: 0.7162 - val_subtask2_output_loss: 0.7569
# Epoch 45/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1686 - subtask1_output_accuracy: 0.7807 - subtask1_output_loss: 0.5182 - subtask2_output_accuracy: 0.7469 - subtask2_output_loss: 0.6503 - val_loss: 1.3749 - val_subtask1_output_accuracy: 0.7430 - val_subtask1_output_loss: 0.6229 - val_subtask2_output_accuracy: 0.7185 - val_subtask2_output_loss: 0.7492
# Epoch 46/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.1256 - subtask1_output_accuracy: 0.7917 - subtask1_output_loss: 0.4946 - subtask2_output_accuracy: 0.7585 - subtask2_output_loss: 0.6310 - val_loss: 1.3621 - val_subtask1_output_accuracy: 0.7465 - val_subtask1_output_loss: 0.6150 - val_subtask2_output_accuracy: 0.7191 - val_subtask2_output_loss: 0.7438
# Epoch 47/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1106 - subtask1_output_accuracy: 0.7960 - subtask1_output_loss: 0.4929 - subtask2_output_accuracy: 0.7608 - subtask2_output_loss: 0.6177 - val_loss: 1.3555 - val_subtask1_output_accuracy: 0.7497 - val_subtask1_output_loss: 0.6129 - val_subtask2_output_accuracy: 0.7237 - val_subtask2_output_loss: 0.7390
# Epoch 48/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1106 - subtask1_output_accuracy: 0.7964 - subtask1_output_loss: 0.4904 - subtask2_output_accuracy: 0.7611 - subtask2_output_loss: 0.6202 - val_loss: 1.3487 - val_subtask1_output_accuracy: 0.7544 - val_subtask1_output_loss: 0.6105 - val_subtask2_output_accuracy: 0.7252 - val_subtask2_output_loss: 0.7342
# Epoch 49/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.1160 - subtask1_output_accuracy: 0.7939 - subtask1_output_loss: 0.4978 - subtask2_output_accuracy: 0.7664 - subtask2_output_loss: 0.6181 - val_loss: 1.3325 - val_subtask1_output_accuracy: 0.7570 - val_subtask1_output_loss: 0.6022 - val_subtask2_output_accuracy: 0.7302 - val_subtask2_output_loss: 0.7254
# Epoch 50/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.0810 - subtask1_output_accuracy: 0.8065 - subtask1_output_loss: 0.4733 - subtask2_output_accuracy: 0.7622 - subtask2_output_loss: 0.6077 - val_loss: 1.3429 - val_subtask1_output_accuracy: 0.7544 - val_subtask1_output_loss: 0.6095 - val_subtask2_output_accuracy: 0.7299 - val_subtask2_output_loss: 0.7294
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.3488 - subtask1_output_accuracy: 0.7440 - subtask1_output_loss: 0.6142 - subtask2_output_accuracy: 0.7266 - subtask2_output_loss: 0.7346
# Subtask 1 - Loss: 0.6156759262084961, Accuracy: 0.7299582362174988
# Subtask 2 - Loss: 0.7492997050285339, Accuracy: 0.7292250394821167

# %%
from sklearn.metrics import classification_report

y1_pred = np.argmax(model.predict(X_test)[0], axis=1)
y2_pred = np.argmax(model.predict(X_test)[1], axis=1)


print("Classification Report for SubTask 1:")
print(classification_report(y1_test, y1_pred, target_names=le1.classes_))

print("\nClassification Report for SubTask 2:")
print(classification_report(y2_test, y2_pred, target_names=le2.classes_))
# Out:
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Classification Report for SubTask 1:
#               precision    recall  f1-score   support
#
#      Neutral       0.69      0.67      0.68      1454
#   Optimistic       0.79      0.88      0.84      1408
#  Pessimistic       0.76      0.70      0.73      1422
#
#     accuracy                           0.75      4284
#    macro avg       0.75      0.75      0.75      4284
# weighted avg       0.75      0.75      0.75      4284
#
#
# Classification Report for SubTask 2:
#               precision    recall  f1-score   support
#
# Appreciation       0.90      0.84      0.87       415
#    Criticism       0.63      0.54      0.58       817
#      Nothing       0.71      0.84      0.77      1933
#    Offensive       0.74      0.50      0.59       605
#   Suggestion       0.80      0.79      0.79       514
#
#     accuracy                           0.73      4284
#    macro avg       0.76      0.70      0.72      4284
# weighted avg       0.73      0.73      0.72      4284

# %% [markdown]
# Bilstm

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, LSTM, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.regularizers import l2
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
import warnings
warnings.filterwarnings('ignore')

dataset = pd.read_csv('/content/cleaned_balanced_dataset.csv')

le1 = LabelEncoder()
dataset['SubTask1_Num'] = le1.fit_transform(dataset['SubTask1'])

le2 = LabelEncoder()
dataset['SubTask2_Num'] = le2.fit_transform(dataset['SubTask2'])

default_subtask2_label = le2.transform(['Nothing'])[0]

model_name = 'sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2'
sbert = SentenceTransformer(model_name)

max_len = 50
embed_dim = 384

tokenized_comments = [word_tokenize(comment.lower()) for comment in dataset['Comments']]
X_sequences = [sbert.encode(tokens, show_progress_bar=False, batch_size=32) for tokens in tokenized_comments]
X_padded = pad_sequences(X_sequences, maxlen=max_len, dtype='float32', padding='post', truncating='post')
X = np.array(X_padded)

y1 = np.array(dataset['SubTask1_Num'].values)
y2 = np.array(dataset['SubTask2_Num'].values)

X_train, X_test, y1_train, y1_test, y2_train, y2_test = train_test_split(
    X, y1, y2, test_size=0.2, random_state=42
)

class_weights1 = compute_class_weight('balanced', classes=np.unique(y1_train), y=y1_train)
class_weight_dict1 = dict(enumerate(class_weights1))

class_weights2 = {}
for label in np.unique(y1_train):
    subset_indices = y1_train == label
    y2_subset = y2_train[subset_indices]
    if len(np.unique(y2_subset)) > 1:
        weights = compute_class_weight('balanced', classes=np.unique(y2_subset), y=y2_subset)
        class_weights2[label] = dict(enumerate(weights, start=0))

def create_bilstm_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Bidirectional(LSTM(64, return_sequences=True, kernel_regularizer=l2(0.01)))(inputs)
    x = Dropout(0.4)(x)
    x = Bidirectional(LSTM(64, return_sequences=False, kernel_regularizer=l2(0.01)))(x)
    x = Dropout(0.4)(x)
    x = Dense(64, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = Dropout(0.4)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

subtask1_model = create_bilstm_model(input_shape=(max_len, embed_dim), num_classes=3)
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

subtask1_model.fit(
    X_train, y1_train,
    validation_split=0.2,
    epochs=50,
    batch_size=32,
    callbacks=[early_stop],
    class_weight=class_weight_dict1,
    verbose=1
)

subtask1_train_preds = np.argmax(subtask1_model.predict(X_train), axis=1)
subtask1_train_accuracy = accuracy_score(y1_train, subtask1_train_preds)
print(f"SubTask1 Training Accuracy: {subtask1_train_accuracy:.4f}")

subtask2_models = {}
subtask2_train_accuracies = {}
for label in np.unique(y1_train):
    subset_indices = y1_train == label
    y2_subset = y2_train[subset_indices]
    if len(np.unique(y2_subset)) > 1:
        subtask2_model = create_bilstm_model(input_shape=(max_len, embed_dim), num_classes=5)
        subtask2_model.fit(
            X_train[subset_indices], y2_subset,
            validation_split=0.2,
            epochs=50,
            batch_size=32,
            callbacks=[early_stop],
            class_weight=class_weights2.get(label, None),
            verbose=1
        )
        subtask2_models[label] = subtask2_model
        subtask2_train_preds = np.argmax(subtask2_model.predict(X_train[subset_indices]), axis=1)
        subtask2_train_accuracies[label] = accuracy_score(y2_subset, subtask2_train_preds)
    else:
        subtask2_train_accuracies[label] = None

for label, acc in subtask2_train_accuracies.items():
    if acc is not None:
        print(f"SubTask2 Training Accuracy (SubTask1 Label {label}): {acc:.4f}")

subtask1_preds = np.argmax(subtask1_model.predict(X_test), axis=1)

subtask2_preds = []
for i, subtask1_pred in enumerate(subtask1_preds):
    if subtask1_pred in subtask2_models:
        subtask2_pred = np.argmax(subtask2_models[subtask1_pred].predict(X_test[i:i+1]), axis=1)[0]
        subtask2_preds.append(subtask2_pred)
    else:
        subtask2_preds.append(default_subtask2_label)

subtask1_test_accuracy = accuracy_score(y1_test, subtask1_preds)
print(f"\nSubTask1 Test Accuracy: {subtask1_test_accuracy:.4f}")
print("SubTask1 Classification Report:")
print(classification_report(y1_test, subtask1_preds, target_names=le1.classes_))

subtask2_test_accuracy = accuracy_score(y2_test, subtask2_preds)
print(f"\nSubTask2 Test Accuracy: {subtask2_test_accuracy:.4f}")
print("SubTask2 Classification Report:")
print(classification_report(y2_test, subtask2_preds, target_names=le2.classes_))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Tokenizing comments and generating embeddings...
# Training BiLSTM for SubTask1...
# Epoch 1/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.3340 - loss: 9.2015 - val_accuracy: 0.4195 - val_loss: 4.4257
# Epoch 2/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.3850 - loss: 3.6522 - val_accuracy: 0.3988 - val_loss: 2.0983
# Epoch 3/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.3962 - loss: 1.8645 - val_accuracy: 0.3959 - val_loss: 1.4048
# Epoch 4/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.4049 - loss: 1.3368 - val_accuracy: 0.3985 - val_loss: 1.2043
# Epoch 5/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.3969 - loss: 1.1840 - val_accuracy: 0.3991 - val_loss: 1.1398
# Epoch 6/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.4130 - loss: 1.1275 - val_accuracy: 0.4110 - val_loss: 1.1021
# Epoch 7/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.4340 - loss: 1.0886 - val_accuracy: 0.4422 - val_loss: 1.0745
# Epoch 8/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.4473 - loss: 1.0723 - val_accuracy: 0.4034 - val_loss: 1.0926
# Epoch 9/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.4421 - loss: 1.0659 - val_accuracy: 0.4463 - val_loss: 1.0609
# Epoch 10/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.4496 - loss: 1.0565 - val_accuracy: 0.4475 - val_loss: 1.0500
# Epoch 11/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.4481 - loss: 1.0509 - val_accuracy: 0.4457 - val_loss: 1.0550
# Epoch 12/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.4445 - loss: 1.0558 - val_accuracy: 0.4320 - val_loss: 1.0582
# Epoch 13/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.4475 - loss: 1.0484 - val_accuracy: 0.4338 - val_loss: 1.0595
# Epoch 14/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.4430 - loss: 1.0470 - val_accuracy: 0.4446 - val_loss: 1.0386
# Epoch 15/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.4506 - loss: 1.0443 - val_accuracy: 0.4519 - val_loss: 1.0392
# Epoch 16/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.4538 - loss: 1.0412 - val_accuracy: 0.4437 - val_loss: 1.0525
# Epoch 17/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.4419 - loss: 1.0412 - val_accuracy: 0.4460 - val_loss: 1.0434
# Epoch 18/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.4475 - loss: 1.0383 - val_accuracy: 0.4592 - val_loss: 1.0354
# Epoch 19/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.4499 - loss: 1.0416 - val_accuracy: 0.4484 - val_loss: 1.0350
# Epoch 20/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.4600 - loss: 1.0341 - val_accuracy: 0.4571 - val_loss: 1.0359
# Epoch 21/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.4508 - loss: 1.0375 - val_accuracy: 0.4656 - val_loss: 1.0308
# Epoch 22/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4627 - loss: 1.0323 - val_accuracy: 0.4586 - val_loss: 1.0330
# Epoch 23/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.4704 - loss: 1.0292 - val_accuracy: 0.4632 - val_loss: 1.0325
# Epoch 24/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.4727 - loss: 1.0335 - val_accuracy: 0.4729 - val_loss: 1.0266
# Epoch 25/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.4712 - loss: 1.0331 - val_accuracy: 0.4787 - val_loss: 1.0256
# Epoch 26/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.4813 - loss: 1.0287 - val_accuracy: 0.4816 - val_loss: 1.0301
# Epoch 27/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.4836 - loss: 1.0254 - val_accuracy: 0.4737 - val_loss: 1.0377
# Epoch 28/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.4828 - loss: 1.0277 - val_accuracy: 0.4805 - val_loss: 1.0387
# Epoch 29/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4887 - loss: 1.0241 - val_accuracy: 0.4939 - val_loss: 1.0203
# Epoch 30/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4919 - loss: 1.0152 - val_accuracy: 0.4921 - val_loss: 1.0170
# Epoch 31/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.5027 - loss: 1.0134 - val_accuracy: 0.4971 - val_loss: 1.0064
# Epoch 32/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.5093 - loss: 1.0070 - val_accuracy: 0.5193 - val_loss: 0.9924
# Epoch 33/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.5238 - loss: 1.0012 - val_accuracy: 0.5411 - val_loss: 0.9675
# Epoch 34/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.5343 - loss: 0.9816 - val_accuracy: 0.5405 - val_loss: 0.9698
# Epoch 35/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.5480 - loss: 0.9721 - val_accuracy: 0.5493 - val_loss: 0.9647
# Epoch 36/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.5596 - loss: 0.9579 - val_accuracy: 0.5333 - val_loss: 0.9766
# Epoch 37/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.5592 - loss: 0.9578 - val_accuracy: 0.5478 - val_loss: 0.9714
# Epoch 38/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.5412 - loss: 0.9644 - val_accuracy: 0.5639 - val_loss: 0.9601
# Epoch 39/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.5557 - loss: 0.9608 - val_accuracy: 0.5610 - val_loss: 0.9445
# Epoch 40/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.5479 - loss: 0.9629 - val_accuracy: 0.5572 - val_loss: 0.9466
# Epoch 41/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.5614 - loss: 0.9482 - val_accuracy: 0.5668 - val_loss: 0.9477
# Epoch 42/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.5600 - loss: 0.9442 - val_accuracy: 0.5519 - val_loss: 0.9598
# Epoch 43/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.5503 - loss: 0.9523 - val_accuracy: 0.5446 - val_loss: 0.9673
# Epoch 44/50
# 429/429 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.5664 - loss: 0.9465 - val_accuracy: 0.5335 - val_loss: 0.9966
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step
# SubTask1 Training Accuracy: 0.5684
# Training BiLSTM for SubTask2 (SubTask1 Label 1)...
# Epoch 1/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.3303 - loss: 10.9494 - val_accuracy: 0.3479 - val_loss: 8.3633
# Epoch 2/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.3238 - loss: 7.8081 - val_accuracy: 0.3670 - val_loss: 6.1095
# Epoch 3/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.3570 - loss: 5.7296 - val_accuracy: 0.3670 - val_loss: 4.5493
# Epoch 4/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.3507 - loss: 4.3073 - val_accuracy: 0.3731 - val_loss: 3.4824
# Epoch 5/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.3500 - loss: 3.3324 - val_accuracy: 0.3714 - val_loss: 2.7553
# Epoch 6/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.3615 - loss: 2.6685 - val_accuracy: 0.3897 - val_loss: 2.2600
# Epoch 7/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.4016 - loss: 2.2065 - val_accuracy: 0.4124 - val_loss: 1.9348
# Epoch 8/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4300 - loss: 1.8907 - val_accuracy: 0.5004 - val_loss: 1.6685
# Epoch 9/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4570 - loss: 1.6906 - val_accuracy: 0.5179 - val_loss: 1.5003
# Epoch 10/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.5080 - loss: 1.5216 - val_accuracy: 0.5432 - val_loss: 1.3909
# Epoch 11/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.5298 - loss: 1.3939 - val_accuracy: 0.5763 - val_loss: 1.2896
# Epoch 12/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5622 - loss: 1.3033 - val_accuracy: 0.5719 - val_loss: 1.2330
# Epoch 13/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5614 - loss: 1.2755 - val_accuracy: 0.5763 - val_loss: 1.1841
# Epoch 14/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5913 - loss: 1.1982 - val_accuracy: 0.5737 - val_loss: 1.1654
# Epoch 15/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5840 - loss: 1.1792 - val_accuracy: 0.5815 - val_loss: 1.1377
# Epoch 16/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6071 - loss: 1.1118 - val_accuracy: 0.5911 - val_loss: 1.1005
# Epoch 17/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6117 - loss: 1.1021 - val_accuracy: 0.6059 - val_loss: 1.0844
# Epoch 18/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6303 - loss: 1.0542 - val_accuracy: 0.6059 - val_loss: 1.0727
# Epoch 19/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.6253 - loss: 1.0552 - val_accuracy: 0.6103 - val_loss: 1.0513
# Epoch 20/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.6266 - loss: 1.0411 - val_accuracy: 0.6382 - val_loss: 1.0219
# Epoch 21/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6651 - loss: 0.9825 - val_accuracy: 0.6242 - val_loss: 1.0037
# Epoch 22/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6792 - loss: 0.9657 - val_accuracy: 0.6207 - val_loss: 1.0044
# Epoch 23/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6718 - loss: 0.9463 - val_accuracy: 0.6425 - val_loss: 0.9706
# Epoch 24/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6910 - loss: 0.9189 - val_accuracy: 0.6922 - val_loss: 0.9162
# Epoch 25/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6888 - loss: 0.9221 - val_accuracy: 0.6853 - val_loss: 0.9077
# Epoch 26/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7124 - loss: 0.8740 - val_accuracy: 0.6556 - val_loss: 0.9415
# Epoch 27/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6961 - loss: 0.8997 - val_accuracy: 0.7140 - val_loss: 0.8616
# Epoch 28/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6950 - loss: 0.8819 - val_accuracy: 0.6940 - val_loss: 0.9350
# Epoch 29/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7323 - loss: 0.8344 - val_accuracy: 0.6940 - val_loss: 0.8748
# Epoch 30/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7264 - loss: 0.8449 - val_accuracy: 0.7175 - val_loss: 0.8564
# Epoch 31/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7312 - loss: 0.8289 - val_accuracy: 0.7010 - val_loss: 0.8799
# Epoch 32/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7340 - loss: 0.8255 - val_accuracy: 0.7446 - val_loss: 0.8085
# Epoch 33/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7612 - loss: 0.7810 - val_accuracy: 0.7585 - val_loss: 0.7861
# Epoch 34/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7426 - loss: 0.8055 - val_accuracy: 0.7254 - val_loss: 0.8301
# Epoch 35/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7717 - loss: 0.7618 - val_accuracy: 0.6548 - val_loss: 1.0643
# Epoch 36/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.7436 - loss: 0.8150 - val_accuracy: 0.7716 - val_loss: 0.7509
# Epoch 37/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7699 - loss: 0.7613 - val_accuracy: 0.7210 - val_loss: 0.8090
# Epoch 38/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7683 - loss: 0.7610 - val_accuracy: 0.7341 - val_loss: 0.8005
# Epoch 39/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7421 - loss: 0.7805 - val_accuracy: 0.7088 - val_loss: 0.8610
# Epoch 40/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7485 - loss: 0.7949 - val_accuracy: 0.7428 - val_loss: 0.7696
# Epoch 41/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7961 - loss: 0.7019 - val_accuracy: 0.7681 - val_loss: 0.7392
# Epoch 42/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7927 - loss: 0.7320 - val_accuracy: 0.7419 - val_loss: 0.7782
# Epoch 43/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7906 - loss: 0.7234 - val_accuracy: 0.7541 - val_loss: 0.7586
# Epoch 44/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7810 - loss: 0.7191 - val_accuracy: 0.7759 - val_loss: 0.7189
# Epoch 45/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8245 - loss: 0.6646 - val_accuracy: 0.7210 - val_loss: 0.7826
# Epoch 46/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8172 - loss: 0.6531 - val_accuracy: 0.7637 - val_loss: 0.7249
# Epoch 47/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7948 - loss: 0.6944 - val_accuracy: 0.7794 - val_loss: 0.7275
# Epoch 48/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7995 - loss: 0.6765 - val_accuracy: 0.7829 - val_loss: 0.7057
# Epoch 49/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8061 - loss: 0.6562 - val_accuracy: 0.7446 - val_loss: 0.7829
# Epoch 50/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7963 - loss: 0.6911 - val_accuracy: 0.7358 - val_loss: 0.7982
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# Training BiLSTM for SubTask2 (SubTask1 Label 2)...
# Epoch 1/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.4656 - loss: 10.9659 - val_accuracy: 0.5988 - val_loss: 8.0781
# Epoch 2/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.5238 - loss: 7.6162 - val_accuracy: 0.5988 - val_loss: 5.8373
# Epoch 3/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5392 - loss: 5.5349 - val_accuracy: 0.5988 - val_loss: 4.2761
# Epoch 4/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5355 - loss: 4.1088 - val_accuracy: 0.5988 - val_loss: 3.1927
# Epoch 5/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5285 - loss: 3.1114 - val_accuracy: 0.5997 - val_loss: 2.4513
# Epoch 6/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5413 - loss: 2.4187 - val_accuracy: 0.5865 - val_loss: 1.9442
# Epoch 7/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.5368 - loss: 1.9471 - val_accuracy: 0.5892 - val_loss: 1.6017
# Epoch 8/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5387 - loss: 1.6291 - val_accuracy: 0.6084 - val_loss: 1.3662
# Epoch 9/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.5507 - loss: 1.4148 - val_accuracy: 0.6049 - val_loss: 1.2079
# Epoch 10/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5800 - loss: 1.2592 - val_accuracy: 0.6040 - val_loss: 1.1003
# Epoch 11/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.5507 - loss: 1.1604 - val_accuracy: 0.6180 - val_loss: 1.0117
# Epoch 12/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.5925 - loss: 1.0756 - val_accuracy: 0.6678 - val_loss: 0.9462
# Epoch 13/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6286 - loss: 1.0053 - val_accuracy: 0.6285 - val_loss: 0.9232
# Epoch 14/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6597 - loss: 0.9492 - val_accuracy: 0.6696 - val_loss: 0.8604
# Epoch 15/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6802 - loss: 0.8994 - val_accuracy: 0.6888 - val_loss: 0.8308
# Epoch 16/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6688 - loss: 0.8847 - val_accuracy: 0.6687 - val_loss: 0.8369
# Epoch 17/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6713 - loss: 0.8746 - val_accuracy: 0.6967 - val_loss: 0.7781
# Epoch 18/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6975 - loss: 0.8220 - val_accuracy: 0.6783 - val_loss: 0.7907
# Epoch 19/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6978 - loss: 0.8081 - val_accuracy: 0.6941 - val_loss: 0.7642
# Epoch 20/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7049 - loss: 0.7902 - val_accuracy: 0.7045 - val_loss: 0.7378
# Epoch 21/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7069 - loss: 0.7846 - val_accuracy: 0.7010 - val_loss: 0.7345
# Epoch 22/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7038 - loss: 0.7698 - val_accuracy: 0.6844 - val_loss: 0.7442
# Epoch 23/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7173 - loss: 0.7637 - val_accuracy: 0.6818 - val_loss: 0.7250
# Epoch 24/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7370 - loss: 0.7269 - val_accuracy: 0.7045 - val_loss: 0.7030
# Epoch 25/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7149 - loss: 0.7382 - val_accuracy: 0.7115 - val_loss: 0.6933
# Epoch 26/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7379 - loss: 0.7099 - val_accuracy: 0.7019 - val_loss: 0.7011
# Epoch 27/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.7345 - loss: 0.7117 - val_accuracy: 0.6976 - val_loss: 0.6959
# Epoch 28/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7213 - loss: 0.7111 - val_accuracy: 0.7107 - val_loss: 0.6772
# Epoch 29/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7381 - loss: 0.6944 - val_accuracy: 0.7142 - val_loss: 0.6750
# Epoch 30/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7407 - loss: 0.6851 - val_accuracy: 0.6984 - val_loss: 0.6749
# Epoch 31/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7253 - loss: 0.6911 - val_accuracy: 0.7115 - val_loss: 0.6651
# Epoch 32/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6989 - loss: 0.7141 - val_accuracy: 0.6949 - val_loss: 0.6790
# Epoch 33/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7540 - loss: 0.6560 - val_accuracy: 0.6836 - val_loss: 0.6810
# Epoch 34/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7351 - loss: 0.6693 - val_accuracy: 0.7002 - val_loss: 0.6574
# Epoch 35/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.7439 - loss: 0.6599 - val_accuracy: 0.6984 - val_loss: 0.6646
# Epoch 36/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.7513 - loss: 0.6461 - val_accuracy: 0.7194 - val_loss: 0.6407
# Epoch 37/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7525 - loss: 0.6516 - val_accuracy: 0.7212 - val_loss: 0.6384
# Epoch 38/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7497 - loss: 0.6415 - val_accuracy: 0.7019 - val_loss: 0.6394
# Epoch 39/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7468 - loss: 0.6440 - val_accuracy: 0.7089 - val_loss: 0.6320
# Epoch 40/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7267 - loss: 0.6662 - val_accuracy: 0.7133 - val_loss: 0.6322
# Epoch 41/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.7568 - loss: 0.6257 - val_accuracy: 0.7203 - val_loss: 0.6229
# Epoch 42/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7473 - loss: 0.6281 - val_accuracy: 0.7177 - val_loss: 0.6158
# Epoch 43/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7664 - loss: 0.6141 - val_accuracy: 0.7133 - val_loss: 0.6227
# Epoch 44/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7696 - loss: 0.6035 - val_accuracy: 0.7045 - val_loss: 0.6388
# Epoch 45/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.7685 - loss: 0.6193 - val_accuracy: 0.7150 - val_loss: 0.6082
# Epoch 46/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7796 - loss: 0.5888 - val_accuracy: 0.7264 - val_loss: 0.6150
# Epoch 47/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7712 - loss: 0.6002 - val_accuracy: 0.7203 - val_loss: 0.6329
# Epoch 48/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7719 - loss: 0.5970 - val_accuracy: 0.7229 - val_loss: 0.6159
# Epoch 49/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7700 - loss: 0.5882 - val_accuracy: 0.7185 - val_loss: 0.6047
# Epoch 50/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7629 - loss: 0.6094 - val_accuracy: 0.7229 - val_loss: 0.5989
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# SubTask2 Training Accuracy (SubTask1 Label 1): 0.8179
# SubTask2 Training Accuracy (SubTask1 Label 2): 0.7770
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# SubTask1 Test Accuracy: 0.5537
# SubTask1 Classification Report:
#               precision    recall  f1-score   support
#
#      Neutral       0.56      0.55      0.56      1454
#   Optimistic       0.54      0.64      0.59      1408
#  Pessimistic       0.56      0.47      0.51      1422
#
#     accuracy                           0.55      4284
#    macro avg       0.55      0.55      0.55      4284
# weighted avg       0.56      0.55      0.55      4284
#
#
# SubTask2 Test Accuracy: 0.5345
# SubTask2 Classification Report:
#               precision    recall  f1-score   support
#
# Appreciation       0.48      0.58      0.52       415
#    Criticism       0.40      0.36      0.38       817
#      Nothing       0.67      0.63      0.65      1933
#    Offensive       0.46      0.35      0.40       605
#   Suggestion       0.43      0.65      0.52       514
#
#     accuracy                           0.53      4284
#    macro avg       0.49      0.51      0.49      4284
# weighted avg       0.54      0.53      0.53      4284
